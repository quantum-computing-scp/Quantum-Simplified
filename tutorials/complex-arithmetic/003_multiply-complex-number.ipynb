# %% [markdown]
# #### Multiply complex number
# **Input**:
#
# 1. A complex number *x=a+bi*
#
# 2. A complex number *y=c+di*
#
# **Goal**: Return the product of *x* and *y* as a complex number

# %%
def multiple_complex_number(x: complex, y: complex)-> complex:
  return x*y

print(multiple_complex_number(2+3j, 4+7j))
# Out:
# (-13+26j)
