# %% [markdown]
# ### Conjugate number
#
# **Input**: A complex number z = a+bi
#
# **Goal**: Return the complex conjugate of z

# %%
def complex_conjugate(x:complex)-> complex:
  return x.conjugate()

print(complex_conjugate(4+5j))
print(complex_conjugate(8-4j))
# Out:
# (4-5j)
# (8+4j)
