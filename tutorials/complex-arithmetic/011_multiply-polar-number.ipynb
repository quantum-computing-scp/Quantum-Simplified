# %% [markdown]
# **Input**:
#
# 1. A complex polar number *x=$r_1$.$e^{i\theta_1}$* where *$r_1$>=0* and -*${\pi}$* <= *${\theta_1}$* <= *${\pi}$*
#
# 2. A complex polar number *y=$r_2$.$e^{i\theta_2}$* where *$r_2$>=0* and -*${\pi}$* <= *${\theta_2}$* <= *${\pi}$*
#
# **Goal**: Return the product of *x* and *y* as a complex polar number $r_3$.$e^{i\theta_3}$

# %%
import math
def multiply_polar_number(r1:float, theta1: float, r2:float, theta2:float):
  a=r1*r2*math.cos(theta1+theta2)
  b=r1*r2*math.sin(theta1+theta2)
  r=math.sqrt(a**2+b**2)
  theta=math.atan2(b,a)
  print(f"r={r}")
  print(f"theta={theta}")
  return complex(a,b)
print(multiply_polar_number(1, math.pi/3, 2, math.pi/6))
# Out:
# r=2.0
# theta=1.5707963267948966
# (1.2246467991473532e-16+2j)
