# %% [markdown]
# ### Add complex numbers
# **Inputs**:
# 1. A complex number *x=a+bi*
#
# 2. A complex number *y=c+di*
#
# **Goal**: Return the sum of *x* and *y* as a complex number

# %%
def add_complex_number(x: complex, y: complex) -> complex:
    return x + y

print(add_complex_number(2 + 3j, 4 + 5j))
# Out:
# (6+8j)
