# %% [markdown]
# #### Find Modulus
#
# **Input**: A complex number *x=a+bi*
#
# **Goal**: Return the modulus of this number x

# %%
import math
def find_module(x: complex)-> float:
  real_x = x.real
  img_x= x.imag
  return math.sqrt(math.pow(real_x, 2)+ math.pow(img_x, 2))

print(find_module(3+4j))
# Out:
# 5.0
